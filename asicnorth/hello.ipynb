# %% [markdown]
# # This is a markdown cell
# ---
# ### You can insert math like $e^{i\pi} + 1 = 0$
# ---
# ### You can insert html like this image
# <img src="https://pavandayal.com/stuff/Doggy.jpg" width=300/>

# %%
# this is a code cell
print("Hello")
